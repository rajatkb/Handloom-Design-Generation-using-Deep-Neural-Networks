# %%
from keras.backend.tensorflow_backend import set_session
import tensorflow as tf
config = tf.ConfigProto()
config.gpu_options.allow_growth = True  # dynamically grow the memory used on the GPU
config.log_device_placement = True  # to log device placement (on which device the operation ran)

sess = tf.Session(config=config)

set_session(sess)  # set this TensorFlow session as the default session for Keras


import numpy as np
import os
import matplotlib.pyplot as plt
import matplotlib.animation as animation
import cv2

import nets
# from img_util import preprocess_image, preprocess_image_for_generating, preprocess_reflect_image, crop_image
# Out:
# Using TensorFlow backend.

# %%
model = nets.image_transform_net(512,512,1e-6)

# %%
for model_weights in os.listdir("Styles For Project"):
    os.mkdir("Results/"+model_weights.split('.')[0])
    for input_file in os.listdir("saree images"):
        if not input_file.split('.')[1] in ['jpeg' , 'jpg' , 'png']:
            continue
        image = plt.imread("saree images/"+input_file)
        image = cv2.resize(image, (512 , 512))
        model.load_weights("Styles For Project/"+model_weights)
        output = model.predict(np.array([image]))[0]
        output = np.array(output , dtype = np.uint8)
        img = cv2.cvtColor(output , cv2.COLOR_BGR2RGB)
        cv2.imwrite('Results/'+model_weights.split('.')[0]+'/'+input_file , img)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-ac08bca369a6> in <module>()
#       7         img = cv2.resize(image, (512 , 512))
#       8         model.load_weights("Styles For Project/"+model_weights)
# ----> 9         output = model.predict(np.array([image]))[0]
#      10         output = np.array(output , dtype = np.uint8)
#      11         img = cv2.cvtColor(output , cv2.COLOR_BGR2RGB)
#
# ~/anaconda3/lib/python3.6/site-packages/keras/engine/training.py in predict(self, x, batch_size, verbose, steps)
#    1147                              'argument.')
#    1148         # Validate user data.
# -> 1149         x, _, _ = self._standardize_user_data(x)
#    1150         if self.stateful:
#    1151             if x[0].shape[0] > batch_size and x[0].shape[0] % batch_size != 0:
#
# ...

# %%
input_file = 'saree images/cropped_1.jpg'

# %%
image = plt.imread(input_file)
plt.figure(figsize=(8,8))
plt.imshow(image)
plt.show()

# %%
def preprocess_image(file , dim=256):
    img = cv2.imread(file)
    img = cv2.cvtColor(img , cv2.COLOR_BGR2RGB)
    img = cv2.resize(img , (dim , dim))
    return img

# %%
x = preprocess_image(input_file, dim = 600)
plt.imshow(x)
plt.show()

# %%
y = net.predict(np.array([x]))

# %%
plt.figure(figsize=(8,8))
plt.imshow(np.array(y[0] , dtype = np.uint8))
plt.show()
